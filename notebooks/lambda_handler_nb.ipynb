# %% [markdown]
# # Ce notebook définit les différents jobs de Lambda.

# %% [markdown]
# ## On commence par **tester les requêtes API de IDFM**

# %%
import requests #librairie permettant d'effectuer des requêtes API
